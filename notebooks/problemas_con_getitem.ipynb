# %%
from pathlib import Path
from typing import Any, Dict
from kedro.io import AbstractDataset
from torch.utils.data import Dataset
import fsspec

from kedro.io.core import get_filepath_str, get_protocol_and_path
import pandas as pd
import os
from PIL import Image

# %%
image_urls=catalog.load('image_urls@pandas')
# Out:
# [11/05/25 14:44:02] INFO     Loading data from image_urls@pandas (CSVDataset)...                ]8;id=267056;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\serpientes_env\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=537276;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\envs\serpientes_env\lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\

# %%
image_urls.columns
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Index(['url', 'observation_id', 'observation_date', 'taxa_id', 'rank', 'name',
#        'label', 'file_name'],
#       dtype='object')

# %%
corrupt_files=[]
nice_files=[]
for idx, row in image_urls.iterrows():
    file_name = row['file_name']
    label = row['label']
    path = Path("""data/01_raw/serpientes_de_colombia_images/""") / label / file_name
    path = path.as_posix()  # ensures forward slashes
    try:
        
        image = Image.open(path).convert('RGB') 
        nice_files.append(path)
    except:
        corrupt_files.append(path)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:6                                                                                    │
# │                                                                                                  │
# │    3 for idx, row in image_urls.iterrows():                                                      │
# │    4 │   file_name = row['file_name']                                                            │
# │    5 │   label = row['label']                                                                    │
# │ ❱  6 │   path = Path(self.path_to_images) / label / file_name                                    │
# │    7 │   path = path.as_posix()  # ensures forward slashes                                       │
# │    8 │   try:                                                                                    │
# ...
