# %%
# %reload_kedro
# Out:
# [06/26/25 11:38:08] INFO     Resolved project path as:                                              ]8;id=505088;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\Lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=139018;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\Lib\site-packages\kedro\ipython\__init__.py#175\175]8;;\
#                              C:\Users\nicolas.betancourt\Documents\GitHub\pytorch\serpientes-de-col
#                              ombia.
#                              To set a different path, run '%reload_kedro <project_root>'
#                     INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=541337;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\Lib\site-packages\kedro_telemetry\plugin.py\plugin.py]8;;\:]8;id=615079;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\Lib\site-packages\kedro_telemetry\plugin.py#233\233]8;;\
# ...

# %%
dense_model=catalog.load('dense_model')
# Out:
#                     INFO     Loading data from dense_model (PytorchModelDataset)...             ]8;id=609246;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\Lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=262309;file://C:\Users\nicolas.betancourt\AppData\Local\anaconda3\Lib\site-packages\kedro\io\data_catalog.py#539\539]8;;\
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ C:\Users\nicolas.betancourt\AppData\Local\anaconda3\Lib\site-packages\kedro\io\core.py:223 in    │
# │ load                                                                                             │
# │                                                                                                  │
# │ C:\Users\nicolas.betancourt\Documents\GitHub\pytorch\serpientes-de-colombia\src\serpientes_de_co │
# │ lombia\datasets\pytorch_model_dataset.py:23 in _load                                             │
# ...
